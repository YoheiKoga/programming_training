# %%
import numpy as np
# import bokeh.plotting as bkh
from bokeh.plotting import figure, output_file, show
bkh.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1333">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0., 1., 100)
y = np.cumsum(np.random.randn(100))

p = figure(title="test line plot", x_axis_label='x', y_axis_label='y')
p.line(x,y)
show(p, notebook_handle=True)
# [Working in the Notebook — Bokeh 1.4.0 documentation](https://docs.bokeh.org/en/latest/docs/user_guide/notebook.html?highlight=notebook_handle#notebook-handles)
# Out:
#   <div class="bk-root" id="cbe8ee0b-86e4-4660-a3e6-e75b6a1fab2d" data-root-id="1478"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %%
# [Quickstart — Bokeh 1.4.0 documentation](https://docs.bokeh.org/en/latest/docs/user_guide/quickstart.html)
from bokeh.plotting import figure, output_file, show

x = [1,2,3,4,5]
y = [6,7,8,9,0]

# output_file("")

p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

p.line(x, y, legend="Temp.", line_width=2)

show(p)
# Out:
# ...
#   <div class="bk-root" id="6093b5db-4972-4b51-be1c-1b4995445d49" data-root-id="1230"></div>
