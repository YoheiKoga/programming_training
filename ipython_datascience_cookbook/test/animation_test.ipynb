# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import seaborn as sns
# %matplotlib inline
# %matplotlib nbagg

custom_style = {'axes.labelcolor': 'white',
                'xtick.color': 'white',
                'ytick.color': 'white'}
sns.set_style("darkgrid", rc=custom_style)
# Out:
# Traceback (most recent call last):
#   File "/Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 389, in process
#     proxy(*args, **kwargs)
#   File "/Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 227, in __call__
#     return mtd(*args, **kwargs)
#   File "/Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/matplotlib/animation.py", line 1560, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
fig = plt.figure()
x = np.arange(0, 10, 0.1)

ims = []
for a in range(50):
    y = np.sin(x - a)
    im = plt.plot(x, y, "r")
    ims.append(im)

ani = animation.ArtistAnimation(fig, ims)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
def update_radius(i, circle):
    circle.radius = i*0.5
    return circle,

fig = plt.gcf()
ax = plt.axes(xlim=(-10,10), ylim=(-10,10))
ax.set_aspect('equal')
circle = plt.Circle((0,0), 0.05)
ax.add_patch(circle)
anim = animation.FuncAnimation(fig, update_radius, fargs=(circle, ), frames=30, interval=10)
anim
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
fig = plt.figure()

ims = []

for i in range(10):
    rand = np.random.randn(100)
    im = plt.plot(rand)
    ims.append(im)

ani = animation.ArtistAnimation(fig, ims, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
fig = plt.figure()

def plot(data):
    plt.cla()
    rand = np.random.randn(100)
    im = plt.plot(rand)
    
ani = animation.FuncAnimation(fig, plot, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.plot(np.random.randn(100))
# Out:
# <img src="data:image/png;base64,..." width="432">
