# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

fig = plt.figure(figsize=(8,4))
m = Basemap(projection='merc',
            resolution='h',
            llcrnrlon=131,
            llcrnrlat=33,
            urcrnrlon=141,
            urcrnrlat=38
           )
m.drawcoastlines(color='lightgray')
m.drawcountries(color='lightgray')
m.fillcontinents(color='white', lake_color='#eeeeee');
m.drawmapboundary(fill_color='#eeeeee')

sumoto_lon = 134.7687
sumoto_lat = 34.3755
hiratsuka_lon = 139.3581
hiratsuka_lat = 35.3587

x1, y1 = m(sumoto_lon, sumoto_lat)
x2, y2 = m(hiratsuka_lon, hiratsuka_lat)
m.plot(x1, y1, 'm.', markersize=10)
m.plot(x2, y2, 'm.', markersize=10)
plt.text(x1 + 10000, y1 + 10000, u"sumoto")
plt.text(x2 + 10000, y2 + 10000, u"hiratsuka")

plt.show()
# fig.savefig('map.png')
# Out:
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature
# %matplotlib inline

fig = plt.figure(figsize=(10,5))
# plt.figure9figsize=(10, 5)
# ax = plt.axes(projection=ccrs.AlbersEqualArea())
ax = plt.axes(projection=ccrs.AlbersEqualArea(
                                central_longitude=139.0,
                                standard_parallels=(0.0, 150.0)
                            ))
ax.add_feature(cartopy.feature.LAND)
ax.add_feature(cartopy.feature.OCEAN)
ax.coastlines()
ax.gridlines()
# fig.savefig('map.png')

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.ticker as mticker
import matplotlib.path as mpath
import numpy as np

# Land data creation for 50m resolution
land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m', edgecolor='face', facecolor=cfeature.COLORS['land'])

# %%
plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND)
ax.coastlines(lw=0.5)
ax.gridlines(linestyle='-', color='gray')
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=139.))
ax.set_extent([120, 150, 20, 50])
ax.add_feature(land_50m)
ax.coastlines(resolution='50m', lw=0.5)
ax.gridlines(xlocs=mticker.MultipleLocator(10),
             ylocs=mticker.MultipleLocator(10),
             linestyle='-',
             color='gray'
            )
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.LambertConformal())
ax.add_feature(cfeature.LAND)
ax.coastlines(lw=0.5)
ax.gridlines(linestyle='--', color='gray')
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.LambertConformal(central_longitude=140.0,
                                               central_latitude=30,
                                               standard_parallels=(30,60)
                                              ))
ax.set_extent([110, 170, 10, 60], ccrs.PlateCarree())
ax.add_feature(land_50m)
ax.coastlines(resolution='50m', lw=0.5)
ax.gridlines(xlocs=mticker.MultipleLocator(10),
             ylocs=mticker.MultipleLocator(10),
             linestyle='-',
             color='gray'
            )
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.Mercator())
ax.add_feature(cfeature.LAND)
ax.coastlines(lw=0.5)
ax.gridlines(linestyle='-', color='gray')

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.Mercator(central_longitude=139.0))
ax.set_extent([110, 170, 10, 60], ccrs.PlateCarree())
ax.add_feature(land_50m)
ax.coastlines(resolution='10m', lw=0.5)
ax.gridlines(xlocs=mticker.MultipleLocator(10),
             ylocs=mticker.MultipleLocator(10),
             linestyle='-',
             color='gray'
            )
plt.show()
# Out:
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/cartopy/io/__init__.py:264: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/10m/physical/ne_10m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.Orthographic())
ax.add_feature(cfeature.LAND)
ax.coastlines(lw=0.5)
ax.gridlines(linestyle='-', color='gray')
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.Orthographic(central_longitude=140, central_latitude=39))
ax.add_feature(cfeature.LAND)
ax.coastlines(lw=0.5)
ax.gridlines(linestyle='-', color='gray')
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.NorthPolarStereo(central_longitude=-180))
ax.set_extent([-180, 180, 20, 90], ccrs.PlateCarree())
ax.add_feature(cfeature.LAND)
ax.coastlines(lw=0.5)
ax.gridlines(linestyle='-', color='gray')

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.SouthPolarStereo())
ax.set_extent([-180, 180, -90, -30], ccrs.PlateCarree())
ax.add_feature(cfeature.LAND)
ax.coastlines(lw=0.5)
ax.gridlines(linestyle='-', color='gray')

theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

df = pd.read_csv("data/Allstorms.ibtracs_wmo.v03r05.csv")

# df[df.columns[[0,1,3,8,9]]].head()

dfs = df.groupby('Serial_Num')
pos = dfs[['Latitude', 'Longitude']].mean()
y, x = pos.values.T
# pos.head()

m = Basemap(projection='mill', llcrnrlat=-65, urcrnrlat=85, llcrnrlon=-180, urcrnrlon=180)
x0, y0 = m(-180, -65)
x1, y1 = m(180, 85)
m.drawcoastlines()
m.fillcontinents(color='#11cea2')
xm, ym = m(x, y)
m.plot(xm, ym, '.r', alpha=.1)
# Out:
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
df.head()
# Out:
#       Serial_Num  Season  Num Basin Sub_basin        Name  \
# 0  1848011S09080    1848    2    SI        MM  XXXX848003
# 1  1848011S09080    1848    2    SI        MM  XXXX848003
# 2  1848011S09080    1848    2    SI        MM  XXXX848003
# 3  1848011S09080    1848    2    SI        MM  XXXX848003
# 4  1848011S09080    1848    2    SI        MM  XXXX848003
#
#               ISO_time Nature  Latitude  Longitude  Wind(WMO)  Pres(WMO)  \
# 0  1848-01-11 06:00:00     NR      -8.6       79.8        0.0        0.0
# 1  1848-01-12 06:00:00     NR      -9.0       78.9        0.0        0.0
# 2  1848-01-13 06:00:00     NR     -10.4       73.2        0.0        0.0
# 3  1848-01-14 06:00:00     NR     -12.8       69.9        0.0        0.0
# 4  1848-01-15 06:00:00     NR     -13.9       68.9        0.0        0.0
#
#     Center  Wind(WMO) Percentile  Pres(WMO) Percentile Track_type
# 0  reunion                -100.0                -100.0       main
# 1  reunion                -100.0                -100.0       main
# 2  reunion                -100.0                -100.0       main
# 3  reunion                -100.0                -100.0       main
# 4  reunion                -100.0                -100.0       main

# %%
h = np.vstack((xm, ym))
kde = st.gaussian_kde(h)

k = 50
tx, ty = np.meshgrid(np.linspace(x0, x1, 2*k), np.linspace(y0, y1, k))
v = kde(np.vstack((tx.ravel(), ty.ravel()))).reshape((k, 2*k))

m.drawcoastlines()
m.fillcontinents(color='#dbc8b2')
xm, ym = m(x, y)
m.imshow(v, origin='lower', extent=[x0, x1, y0, y1], cmap=plt.get_cmap('Reds'))
# Out:
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3296: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3305: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

df = pd.read_csv("data/Allstorms.ibtracs_wmo.v03r09.csv")

df[df.columns[[0,1,3,8,9]]].head()

dfs = df.groupby('Serial_Num')
pos = dfs[['Latitude', 'Longitude']].mean()
y, x = pos.values.T
# pos.head()

m = Basemap(projection='mill', llcrnrlat=-65, urcrnrlat=85, llcrnrlon=-180, urcrnrlon=180)
x0, y0 = m(-180, -65)
x1, y1 = m(180, 85)
m.drawcoastlines()
m.fillcontinents(color='#11cea2')
xm, ym = m(x, y)
m.plot(xm, ym, '.r', alpha=.1)
# Out:
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
h = np.vstack((xm, ym))
kde = st.gaussian_kde(h)

k = 50
tx, ty = np.meshgrid(np.linspace(x0, x1, 2*k), np.linspace(y0, y1, k))
v = kde(np.vstack((tx.ravel(), ty.ravel()))).reshape((k, 2*k))

m.drawcoastlines()
m.fillcontinents(color='#dbc8b2')
xm, ym = m(x, y)
m.imshow(v, origin='lower', extent=[x0, x1, y0, y1], cmap=plt.get_cmap('Reds'))
# Out:
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3296: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yk/.virtualenvs/cv/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3305: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
